# %% [markdown]
# # Drawing Flowering Tree By Using Python Turtle Graphics-Chinmayee Nayak

# %%
# Importing libraries
import random
from math import sqrt
from turtle import *

# Debug mode and constants for branch length, sun radius, and magic factor
DEBUG = False
BRANCH_LENGTH = 60
SUN_RADIUS = 40
MAGIC = 12

class FloweringTree:
    def __init__(self):
 # Initialize petal count and borders    
        self.petal_count = 0
        self.petal_left_border = 0.0
        self.petal_right_border = 0.0       
# Create turtle and screen      
        self.turtle = Turtle()
        self.frame = Screen()
 # Set tracer for debugging or normal mode
        if DEBUG:
            self.frame.tracer(0, 0)
        else:
            self.frame.tracer(3, 0)
 # Set background color
        self.frame.bgcolor('black')
        self.turtle.up()  # Lift the pen up to move without drawing

    def tree(self, branch_len):
          # Draw branches recursively
        if branch_len > 3:
            if 8 <= branch_len <= 12:
                if random.randint(0, 2) == 0:
                    self.turtle.color('snow')
                else:
                    self.turtle.color('lightcoral')
                self.turtle.pensize(branch_len / 3)
            elif branch_len < 8:
                self.petal_count += 1
                cur_x = self.turtle.pos()[0]
                if cur_x < 0:
                    self.petal_left_border = min(self.petal_left_border, cur_x)
                else:
                    self.petal_right_border = max(self.petal_right_border, cur_x)
                if random.randint(0, 1) == 0:
                    self.turtle.color('snow')
                else:
                    self.turtle.color('lightcoral')
                self.turtle.pensize(branch_len / 2)
            else:
                self.turtle.color('sienna')
                self.turtle.pensize(branch_len / 10)

            self.turtle.down()
            self.turtle.forward(branch_len)
            self.turtle.up() # Lift the pen up to move without drawing

            random_angle = 3 + 2 * MAGIC * random.random()
            random_length = MAGIC * random.random()

            self.turtle.right(random_angle)
            self.tree(branch_len - random_length)
            self.turtle.left(2 * random_angle)
            self.tree(branch_len - random_length)
            self.turtle.right(random_angle)

            self.turtle.up()
            self.turtle.backward(branch_len)

    def petal_field(self, count, left_border=-100.0, right_border=100.0):
        # Draw petals at the base of the tree
        middle = (right_border + left_border) / 2
        frame_width = (right_border - left_border) / 3
        depth = int(sqrt(frame_width))
        _start_pos = self.turtle.pos()
        start_pos = (middle, _start_pos[1] + depth / 2 - BRANCH_LENGTH / 10)
        self.turtle.goto(start_pos)

        for _ in range(count):
            random_width = frame_width - 2 * frame_width * random.random()
            random_depth = depth - 2 * depth * random.random()
            self.turtle.forward(random_depth)
            self.turtle.left(90)
            self.turtle.forward(random_width)
            self.turtle.down()
            if random.randint(0, 1) == 0:
                self.turtle.color("snow")
            else:
                self.turtle.color("lightcoral")
            rand_size = random.random()
            self.turtle.pensize(2.5 * rand_size)
            self.turtle.begin_fill()
            self.turtle.circle(rand_size)
            self.turtle.end_fill()
            self.turtle.up()
            self.turtle.right(90)
            self.turtle.goto(start_pos)

        self.turtle.goto(_start_pos)
        self.turtle.color('sienna')
        self.turtle.pensize(BRANCH_LENGTH // 10)
        self.turtle.down()
        self.turtle.forward(BRANCH_LENGTH)
        self.turtle.up()

    def the_sun(self, radius=30):
         # Draw the sun
        start_pos = self.turtle.pos()
        self.turtle.forward(500)
        self.turtle.left(90)
        self.turtle.forward(300)
        self.turtle.down()
        self.turtle.color('red')
        self.turtle.begin_fill()
        self.turtle.circle(radius)
        self.turtle.end_fill()
        self.turtle.color('lightcoral')
        self.turtle.up()
        self.turtle.right(90)
        self.turtle.goto(start_pos)

    def signature(self):
        # Signature (can be customized)
        start_pos = self.turtle.pos()
        self.turtle.color('sienna')
        self.turtle.goto(start_pos)

    def snowfall(self):
           # Draw snowfall
        self.turtle.color('white')
        self.turtle.up()
        self.turtle.goto(-400, 400)
        for _ in range(100):
            x = random.randint(-400, 400)
            y = random.randint(-400, 400)
            self.turtle.goto(x, y)
            self.turtle.dot(random.randint(2, 5))

    def draw(self):
         # Main drawing function
        try:
            self.turtle.left(90)
            self.turtle.backward(250)
            self.the_sun(SUN_RADIUS) # Draw the sun
            self.tree(BRANCH_LENGTH)  # Draw the tree
            self.petal_count = self.petal_count // (int(sqrt(2 * MAGIC)))
            self.petal_field(self.petal_count, self.petal_left_border, self.petal_right_border)
            self.turtle.backward(100)
            self.signature() # Add signature
            self.turtle.color('wheat')
            self.turtle.down()
            self.turtle.forward(20)
            self.snowfall()  # Draw snowfall
            self.frame.exitonclick()
        except KeyboardInterrupt:
            print('Keyboard Interrupt.')

if __name__ == '__main__':
    flowering_tree = FloweringTree()
    flowering_tree.draw()

# %% [markdown]
# # Explanation

# %% [raw]
# 1.Imports:
#
# The script imports the necessary modules: random for randomness, sqrt from math for calculations, and everything from turtle for drawing.
#
# 2.Constants:
#
# - DEBUG: A flag to enable or disable debugging mode.
# - BRANCH_LENGTH: The initial length of the branches.
# - SUN_RADIUS: The radius of the sun.
# - MAGIC: A factor used to control the randomness of branch angles and lengths.
#
# 3.FloweringTree Class:
#
# Initialization (__init__ method):
#
# - Sets up the initial state, including petal count and borders.
# - Initializes the turtle and screen.
# - Configures the screen's tracer and background color.
# - Lifts the turtle pen to move without drawing.
#
# Tree Drawing (tree method):
#
# - Recursively draws branches with varying thickness and color based on the branch length.
# - Uses random angles and lengths for sub-branches.
#
# Petal Field (petal_field method):
#
# - Draws petals at the base of the tree with random positions and sizes.
#
# Sun Drawing (the_sun method):
#
# - Draws a red circle representing the sun at a fixed position.
#
# Signature (signature method):
#
# - Adds a signature to the drawing (customizable).
#
# Snowfall (snowfall method):
#
# - Creates a snowfall effect by drawing white dots at random positions.
#
# Main Drawing (draw method):
#
# - Coordinates the overall drawing process: draws the tree, sun, petals, signature, and snowfall.
# - Handles keyboard interrupts to allow exiting the program gracefully.
#
# 4.Execution (if __name__ == '__main__':):
#
# - Creates an instance of FloweringTree and calls the draw method to start the drawing process.
